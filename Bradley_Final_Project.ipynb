# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('Latest_Papa_GP02HYPM-WFP03-04-CTDPFL000-telemetered-ctdpf_ckl_wfp_instrument_20180827T160002-20180909T055531.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,11]
plt.xlabel("Time (UTC)")
plt.ylabel("Pressure (bar)")
plt.title("Papa Oldest Pressure vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Latest_Papa_GP02HYPM-WFP03-04-CTDPFL000-telemetered-ctdpf_ckl_wfp_instrument_20180827T160002-20180909T055531.csv', delimiter = ",",skiprows=1,usecols=[11])
np.mean(data)
# Out:
# 3099.50934375

# %%
data = np.loadtxt('Oldest_Papa_GP02HYPM-WFP03-04-CTDPFL000-telemetered-ctdpf_ckl_wfp_instrument_20130726T150003-20130803T165600.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,11]
plt.xlabel("Time (UTC)")
plt.ylabel("Pressure (bar)")
plt.title("Papa Latest Pressure vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Oldest_Papa_GP02HYPM-WFP03-04-CTDPFL000-telemetered-ctdpf_ckl_wfp_instrument_20130726T150003-20130803T165600.csv', delimiter = ",",skiprows=1,usecols=[11])
np.mean(data)
# Out:
# 3207.9819939271256

# %%
data = np.loadtxt('Latest_Papa_GP02HYPM-WFP03-04-CTDPFL000-telemetered-ctdpf_ckl_wfp_instrument_20180827T160002-20180909T055531.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,12]
plt.xlabel("Time (UTC)")
plt.ylabel("Temperature (Deg C)")
plt.title("Papa Oldest Tempurature vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Latest_Papa_GP02HYPM-WFP03-04-CTDPFL000-telemetered-ctdpf_ckl_wfp_instrument_20180827T160002-20180909T055531.csv', delimiter = ",",skiprows=1,usecols=[12])
np.mean(data)
# Out:
# 1.626214375

# %%
data = np.loadtxt('Oldest_Papa_GP02HYPM-WFP03-04-CTDPFL000-telemetered-ctdpf_ckl_wfp_instrument_20130726T150003-20130803T165600.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,12]
plt.xlabel("Time (UTC)")
plt.ylabel("Temperature (Deg C)")
plt.title("Papa Latest Temperature vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Oldest_Papa_GP02HYPM-WFP03-04-CTDPFL000-telemetered-ctdpf_ckl_wfp_instrument_20130726T150003-20130803T165600.csv', delimiter = ",",skiprows=1,usecols=[12])
np.mean(data)
# Out:
# 1.5820363360323888

# %%
data = np.loadtxt('Latest_Papa_GP02HYPM-WFP03-04-CTDPFL000-telemetered-ctdpf_ckl_wfp_instrument_20180827T160002-20180909T055531.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,15]
plt.xlabel("Time (UTC)")
plt.ylabel("Density (Kg*m^3)")
plt.title("Papa Oldest Density vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Latest_Papa_GP02HYPM-WFP03-04-CTDPFL000-telemetered-ctdpf_ckl_wfp_instrument_20180827T160002-20180909T055531.csv', delimiter = ",",skiprows=1,usecols=[15])
np.mean(data)
# Out:
# 1041.848967625

# %%
data = np.loadtxt('Oldest_Papa_GP02HYPM-WFP03-04-CTDPFL000-telemetered-ctdpf_ckl_wfp_instrument_20130726T150003-20130803T165600.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,15]
plt.xlabel("Time (UTC)")
plt.ylabel("Density (Kg*m^3)")
plt.title("Papa Latest Density vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Oldest_Papa_GP02HYPM-WFP03-04-CTDPFL000-telemetered-ctdpf_ckl_wfp_instrument_20130726T150003-20130803T165600.csv', delimiter = ",",skiprows=1,usecols=[15])
np.mean(data)
# Out:
# 1042.311133096154

# %%
data = np.loadtxt('Oldest_Argentine_GA02HYPM-WFP03-04-CTDPFL000-recovered_wfp-ctdpf_ckl_wfp_instrument_recovered_20150316T230003-20150329T185313.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,11]
plt.xlabel("Time (UTC)")
plt.ylabel("Pressure (bar)")
plt.title("Argentine Oldest Pressure vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Oldest_Argentine_GA02HYPM-WFP03-04-CTDPFL000-recovered_wfp-ctdpf_ckl_wfp_instrument_recovered_20150316T230003-20150329T185313.csv', delimiter = ",",skiprows=1,usecols=[11])
np.mean(data)
# Out:
# 3890.0279435368566

# %%
data = np.loadtxt('Latest_Argentine_GA02HYPM-WFP03-04-CTDPFL000-recovered_wfp-ctdpf_ckl_wfp_instrument_recovered_20150928T040002-20151011T143445.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,11]
plt.xlabel("Time (UTC)")
plt.ylabel("Pressure (bar)")
plt.title("Argentine Latest Pressure vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Latest_Argentine_GA02HYPM-WFP03-04-CTDPFL000-recovered_wfp-ctdpf_ckl_wfp_instrument_recovered_20150928T040002-20151011T143445.csv', delimiter = ",",skiprows=1,usecols=[11])
np.mean(data)
# Out:
# 3903.5521925955945

# %%
data = np.loadtxt('Oldest_Argentine_GA02HYPM-WFP03-04-CTDPFL000-recovered_wfp-ctdpf_ckl_wfp_instrument_recovered_20150316T230003-20150329T185313.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,12]
plt.xlabel("Time (UTC)")
plt.ylabel("Temperature (Deg C)")
plt.title("Argentine Oldest Temperature vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Oldest_Argentine_GA02HYPM-WFP03-04-CTDPFL000-recovered_wfp-ctdpf_ckl_wfp_instrument_recovered_20150316T230003-20150329T185313.csv', delimiter = ",",skiprows=1,usecols=[12])
np.mean(data)
# Out:
# 0.8541304061330656

# %%
data = np.loadtxt('Latest_Argentine_GA02HYPM-WFP03-04-CTDPFL000-recovered_wfp-ctdpf_ckl_wfp_instrument_recovered_20150928T040002-20151011T143445.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,12]
plt.xlabel("Time (UTC)")
plt.ylabel("Temperature (Deg C)")
plt.title("Argentine Latest Temperature vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Latest_Argentine_GA02HYPM-WFP03-04-CTDPFL000-recovered_wfp-ctdpf_ckl_wfp_instrument_recovered_20150928T040002-20151011T143445.csv', delimiter = ",",skiprows=1,usecols=[12])
np.mean(data)
# Out:
# 0.8181388981596263

# %%
data = np.loadtxt('Oldest_Argentine_GA02HYPM-WFP03-04-CTDPFL000-recovered_wfp-ctdpf_ckl_wfp_instrument_recovered_20150316T230003-20150329T185313.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,15]
plt.xlabel("Time (UTC)")
plt.ylabel("Density (Kg*m^3)")
plt.title("Argentine Oldest Density vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Oldest_Argentine_GA02HYPM-WFP03-04-CTDPFL000-recovered_wfp-ctdpf_ckl_wfp_instrument_recovered_20150316T230003-20150329T185313.csv', delimiter = ",",skiprows=1,usecols=[15])
np.mean(data)
# Out:
# 1045.3290821040857

# %%
data = np.loadtxt('Latest_Argentine_GA02HYPM-WFP03-04-CTDPFL000-recovered_wfp-ctdpf_ckl_wfp_instrument_recovered_20150928T040002-20151011T143445.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,15]
plt.xlabel("Time (UTC)")
plt.ylabel("Density (Kg*m^3)")
plt.title("Argentine Latest Density vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Latest_Argentine_GA02HYPM-WFP03-04-CTDPFL000-recovered_wfp-ctdpf_ckl_wfp_instrument_recovered_20150928T040002-20151011T143445.csv', delimiter = ",",skiprows=1,usecols=[15])
np.mean(data)
# Out:
# 1045.5540857503217

# %%
data = np.loadtxt('Oldest_Southern_Ocean_instrument_recovered_20150220T020003-20150301T152553.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,11]
plt.xlabel("Time (UTC)")
plt.ylabel("Pressure (bar)")
plt.title("Southern Oldest Pressure vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Oldest_Southern_Ocean_instrument_recovered_20150220T020003-20150301T152553.csv', delimiter = ",",skiprows=1,usecols=[11])
np.mean(data)
# Out:
# 3357.317516595882

# %%
data = np.loadtxt('Latest_Southern_instrument_recovered_20161024T000002-20161106T105538.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,11]
plt.xlabel("Time (UTC)")
plt.ylabel("Pressure (bar)")
plt.title("Southern Latest Pressure vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Latest_Southern_instrument_recovered_20161024T000002-20161106T105538.csv', delimiter = ",",skiprows=1,usecols=[11])
np.mean(data)
# Out:
# 3319.2563973302485

# %%
data = np.loadtxt('Oldest_Southern_Ocean_instrument_recovered_20150220T020003-20150301T152553.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,12]
plt.xlabel("Time (UTC)")
plt.ylabel("Temperature (Deg C)")
plt.title("Southern Oldest Temperature vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Oldest_Southern_Ocean_instrument_recovered_20150220T020003-20150301T152553.csv', delimiter = ",",skiprows=1,usecols=[12])
np.mean(data)
# Out:
# 1.41266299475356

# %%
data = np.loadtxt('Latest_Southern_instrument_recovered_20161024T000002-20161106T105538.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,12]
plt.xlabel("Time (UTC)")
plt.ylabel("Temperature (Deg C)")
plt.title("Southern Latest Temperature vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Latest_Southern_instrument_recovered_20161024T000002-20161106T105538.csv', delimiter = ",",skiprows=1,usecols=[12])
np.mean(data)
# Out:
# 1.4469025612197148

# %%
data = np.loadtxt('Oldest_Southern_Ocean_instrument_recovered_20150220T020003-20150301T152553.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,15]
plt.xlabel("Time (UTC)")
plt.ylabel("Density (Kg*m^3)")
plt.title("Southern Oldest Density vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Oldest_Southern_Ocean_instrument_recovered_20150220T020003-20150301T152553.csv', delimiter = ",",skiprows=1,usecols=[15])
np.mean(data)
# Out:
# 1043.05559739086

# %%
data = np.loadtxt('Latest_Southern_instrument_recovered_20161024T000002-20161106T105538.csv', delimiter = ",",skiprows=1,usecols=range(0,16))
x=data[:,1]
y=data[:,15]
plt.xlabel("Time (UTC)")
plt.ylabel("Density (Kg*m^3)")
plt.title("Southern Latest Density vs Time")
plt.plot(x,y)

# %%
data = np.loadtxt('Latest_Southern_instrument_recovered_20161024T000002-20161106T105538.csv', delimiter = ",",skiprows=1,usecols=[15])
np.mean(data)
# Out:
# 1042.910468735423
